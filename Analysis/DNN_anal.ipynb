# %%
import pandas as pd

# %%
data = pd.read_csv('DATA/act_labeling_data_fix.csv',encoding='cp949')

# %%
data
# Out:
#        CUSTNO            GNO  CBSCORE  CBSCOREGRD  CREDITOTAMT  YSALEAMT  \
# 0      475821  l180202101898      945           1           20      2038
# 1       74417  l230201700120      894           2           19      1175
# 2      387787  l110201603233      906           1            0       763
# 3      395418  l230201700254      881           2           14       724
# 4      190372  l200201601418      725           6            7       335
# ...       ...            ...      ...         ...          ...       ...
# 39112  514919  l240201902522      865           3            0         0
# 39113  357361  l160201601877      780           5           11         0
# 39114  340606  l270201900572      733           6            9         0
# 39115  505207  l190201902523      948           1            0         0
# 39116  498678  l110201903609      896           2            5         0
#
#        ESTMM  ASSETAMT  IMSAAMT  IMJUAMT  ...      환율       GDP  소상공인체감지수  \
# ...

# %%
new_data=[(475821,	'l180202101898',	945,	1,	20,	2038,	37,	10,	10,	0,	0,0,0,17000000,1,'A',3,0,0,3286.68,1129.9,	476244.6,	51.40,	3.7,	107.39,	1.30,	87.1,	110.3	,3),
(475821,	'l180202101898',	945,	1,	20,	2038,	37,	10,	10,	0,	0,0,0,17000000,1,'B',3,0,0,3286.68,1129.9,	476244.6,	51.40,	3.7,	107.39,	1.30,	87.1,	110.3	,3),
(475821,	'l180202101898',	945,	1,	20,	2038,	37,	10,	10,	0,	0,0,0,17000000,1,'C',3,0,0,3286.68,1129.9,	476244.6,	51.40,	3.7,	107.39,	1.30,	87.1,	110.3	,3),
(475821,	'l180202101898',	945,	1,	20,	2038,	37,	10,	10,	0,	0,0,0,17000000,1,'D',3,0,0,3286.68,1129.9,	476244.6,	51.40,	3.7,	107.39,	1.30,	87.1,	110.3	,3),
(475821,	'l180202101898',	945,	1,	20,	2038,	37,	10,	10,	0,	0,0,0,17000000,1,'E',3,0,0,3286.68,1129.9,	476244.6,	51.40,	3.7,	107.39,	1.30,	87.1,	110.3	,3),
(475821,	'l180202101898',	945,	1,	20,	2038,	37,	10,	10,	0,	0,0,0,17000000,1,'F',3,0,0,3286.68,1129.9,	476244.6,	51.40,	3.7,	107.39,	1.30,	87.1,	110.3	,3),
(475821,	'l180202101898',	945,	1,	20,	2038,	37,	10,	10,	0,	0,0,0,17000000,1,'G',3,0,0,3286.68,1129.9,	476244.6,	51.40,	3.7,	107.39,	1.30,	87.1,	110.3	,3),
(475821,	'l180202101898',	945,	1,	20,	2038,	37,	10,	10,	0,	0,0,0,17000000,1,'H',3,0,0,3286.68,1129.9,	476244.6,	51.40,	3.7,	107.39,	1.30,	87.1,	110.3	,3),
(475821,	'l180202101898',	945,	1,	20,	2038,	37,	10,	10,	0,	0,0,0,17000000,1,'I',3,0,0,3286.68,1129.9,	476244.6,	51.40,	3.7,	107.39,	1.30,	87.1,	110.3	,3),
(475821,	'l180202101898',	945,	1,	20,	2038,	37,	10,	10,	0,	0,0,0,17000000,1,'J',3,0,0,3286.68,1129.9,	476244.6,	51.40,	3.7,	107.39,	1.30,	87.1,	110.3	,3),
(475821,	'l180202101898',	945,	1,	20,	2038,	37,	10,	10,	0,	0,0,0,17000000,1,'K',3,0,0,3286.68,1129.9,	476244.6,	51.40,	3.7,	107.39,	1.30,	87.1,	110.3	,3),
(475821,	'l180202101898',	945,	1,	20,	2038,	37,	10,	10,	0,	0,0,0,17000000,1,'L',3,0,0,3286.68,1129.9,	476244.6,	51.40,	3.7,	107.39,	1.30,	87.1,	110.3	,3),
(475821,	'l180202101898',	945,	1,	20,	2038,	37,	10,	10,	0,	0,0,0,17000000,1,'M',3,0,0,3286.68,1129.9,	476244.6,	51.40,	3.7,	107.39,	1.30,	87.1,	110.3	,3),
(475821,	'l180202101898',	945,	1,	20,	2038,	37,	10,	10,	0,	0,0,0,17000000,1,'N',3,0,0,3286.68,1129.9,	476244.6,	51.40,	3.7,	107.39,	1.30,	87.1,	110.3	,3),
(475821,	'l180202101898',	945,	1,	20,	2038,	37,	10,	10,	0,	0,0,0,17000000,1,'O',3,0,0,3286.68,1129.9,	476244.6,	51.40,	3.7,	107.39,	1.30,	87.1,	110.3	,3),
(475821,	'l180202101898',	945,	1,	20,	2038,	37,	10,	10,	0,	0,0,0,17000000,1,'P',3,0,0,3286.68,1129.9,	476244.6,	51.40,	3.7,	107.39,	1.30,	87.1,	110.3	,3),
(475821,	'l180202101898',	945,	1,	20,	2038,	37,	10,	10,	0,	0,0,0,17000000,1,'Q',3,0,0,3286.68,1129.9,	476244.6,	51.40,	3.7,	107.39,	1.30,	87.1,	110.3	,3),
(475821,	'l180202101898',	945,	1,	20,	2038,	37,	10,	10,	0,	0,0,0,17000000,1,'R',3,0,0,3286.68,1129.9,	476244.6,	51.40,	3.7,	107.39,	1.30,	87.1,	110.3	,3),
(475821,	'l180202101898',	945,	1,	20,	2038,	37,	10,	10,	0,	0,0,0,17000000,1,'S',3,0,0,3286.68,1129.9,	476244.6,	51.40,	3.7,	107.39,	1.30,	87.1,	110.3	,3),
(475821,	'l180202101898',	945,	1,	20,	2038,	37,	10,	10,	0,	0,0,0,17000000,1,'T',3,0,0,3286.68,1129.9,	476244.6,	51.40,	3.7,	107.39,	1.30,	87.1,	110.3	,3),
]

# %%
len(new_data)
# Out:
# 29

# %%
data. new_data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6800/1876467745.py in <module>
# ----> 1 data[len(data)]= new_data
#
# ~\anaconda3\envs\Study_Big\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3605         else:
#    3606             # set column
# -> 3607             self._set_item(key, value)
#    3608
#    3609     def _setitem_slice(self, key: slice, value):
#
# ~\anaconda3\envs\Study_Big\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3777         ensure homogeneity.
#    3778         """
# -> 3779         value = self._sanitize_column(value)
#    3780
#    3781         if (
#
# ~\anaconda3\envs\Study_Big\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, value)
#    4502
#    4503         if is_list_like(value):
# ...
