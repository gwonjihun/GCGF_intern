# %%
import pandas as pd
from sklearn.preprocessing import RobustScaler

# %%
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("DATA/act_labeling_data_fix.csv",encoding="cp949")

# %%
scaler_data = data[[ 'CBSCORE', 'CREDITOTAMT', 'YSALEAMT',
       'ESTMM', 'ASSETAMT', 'IMSAAMT', 'IMJUAMT', 'BUSAAMT', 'BUJUAMT',
       'BU1TOTAMT', 'GAMT', 'GKIND', 'LABORCNT', 'ACTCD','KOSPI', '환율', 'GDP', 
       '소상공인체감지수', '실업률', '물가지수', '국고채', '금리', '유가등락률',
       '소비자심리지수']]

# %%
scaler = RobustScaler()
scaler = scaler.fit_transform(scaler_data)

# %%
data.head()
# Out:
#    CUSTNO            GNO  CBSCORE  CBSCOREGRD  CREDITOTAMT  YSALEAMT  ESTMM  \
# 0  475821  l180202101898      945           1           20      2038     37
# 1   74417  l230201700120      894           2           19      1175      9
# 2  387787  l110201603233      906           1            0       763    185
# 3  395418  l230201700254      881           2           14       724     11
# 4  190372  l200201601418      725           6            7       335    167
#
#    ASSETAMT  IMSAAMT  IMJUAMT  ...      환율       GDP  소상공인체감지수  실업률    물가지수  \
# 0        10       10        0  ...  1129.9  476244.6      51.4  3.7  107.39
# 1        25        0       25  ...  1151.9  435062.1      53.8  3.9  102.92
# 2        10       10        0  ...  1170.3  430914.8      72.6  3.7  101.45
# 3        10       10        0  ...  1151.2  435062.1      76.2  3.6  102.85
# 4        80        2        0  ...  1148.1  428335.7      63.2  3.6  100.60
#
#     국고채    금리  유가등락률 소비자심리지수  ONEHOT
# ...

# %%
data[[ 'CBSCORE', 'CREDITOTAMT', 'YSALEAMT',
       'ESTMM', 'ASSETAMT', 'IMSAAMT', 'IMJUAMT', 'BUSAAMT', 'BUJUAMT',
       'BU1TOTAMT', 'GAMT', 'GKIND', 'LABORCNT', 'ACTCD','KOSPI', '환율', 'GDP', 
       '소상공인체감지수', '실업률', '물가지수', '국고채', '금리', '유가등락률',
       '소비자심리지수']]=scaler

# %%
data.head()
# Out:
#    CUSTNO            GNO   CBSCORE  CBSCOREGRD  CREDITOTAMT   YSALEAMT  \
# 0  475821  l180202101898  1.015873           1     0.230769  10.743169
# 1   74417  l230201700120  0.206349           2     0.205128   6.027322
# 2  387787  l110201603233  0.396825           1    -0.282051   3.775956
# 3  395418  l230201700254  0.000000           2     0.076923   3.562842
# 4  190372  l200201601418 -2.476190           6    -0.102564   1.437158
#
#       ESTMM  ASSETAMT  IMSAAMT  IMJUAMT  ...        환율       GDP  소상공인체감지수  \
# 0  0.014085 -0.176471      0.0      0.0  ...  0.009592  1.885958 -1.172285
# 1 -0.380282 -0.088235     -0.5     25.0  ...  0.537170 -0.901805 -0.992509
# 2  2.098592 -0.176471      0.0      0.0  ...  0.978417 -1.182547  0.415730
# 3 -0.352113 -0.176471      0.0      0.0  ...  0.520384 -0.901805  0.685393
# 4  1.845070  0.235294     -0.4      0.0  ...  0.446043 -1.357134 -0.288390
#
#         실업률      물가지수       국고채   금리     유가등락률   소비자심리지수  ONEHOT
# ...

# %%
import seaborn as sns

# %%
df_bu = data[data['ACTCD']==1]

# %%
print(df_bu.columns)
'''cbscore, ysaleamt, creditotamt,estmm,assetamt,imsaamt,imjuamt,busaamt,bujuamt,kospi,환율,gdp,체감지수 실업률 물가지수 국고채 금리 유가 등락률 소비자심리지수 onehot'''
# Out:
# Index(['CUSTNO', 'GNO', 'CBSCORE', 'CBSCOREGRD', 'CREDITOTAMT', 'YSALEAMT',
#        'ESTMM', 'ASSETAMT', 'IMSAAMT', 'IMJUAMT', 'BUSAAMT', 'BUJUAMT',
#        'BU1TOTAMT', 'GAMT', 'GKIND', 'BIZNML_x', 'LABORCNT', 'ACTCD', 'ACTKND',
#        'KOSPI', '환율', 'GDP', '소상공인체감지수', '실업률', '물가지수', '국고채', '금리', '유가등락률',
#        '소비자심리지수', 'ONEHOT'],
#       dtype='object')
# 'cbscore, ysaleamt, creditotamt,estmm,assetamt,imsaamt,imjuamt,busaamt,bujuamt,kospi,환율,gdp,체감지수 실업률 물가지수 국고채 금리 유가 등락률 소비자심리지수 onehot'

# %%
plt.subplot(5,5,1)
sns.kdeplot(data['CBSCORE'],color="green")
sns.kdeplot(df_bu['CBSCORE'],color="red")
CB_mean = round(data['CBSCORE'].mean()- df_bu['CBSCORE'].mean(),6)
plt.text(0.1,0.01,str(CB_mean))
plt.show()

# %%
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/gulim.ttc"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font',family=font)

# %%
import matplotlib.font_manager as fm

# 설치된 폰트 출력
font_list = [font.name for font in fm.fontManager.ttflist]
font_list
# Out:
# ['STIXSizeTwoSym',
#  'cmtt10',
#  'STIXGeneral',
#  'STIXSizeFourSym',
#  'STIXSizeFourSym',
#  'cmb10',
#  'DejaVu Sans',
#  'STIXSizeThreeSym',
#  'cmsy10',
#  'STIXNonUnicode',
#  'DejaVu Sans Mono',
#  'cmex10',
#  'DejaVu Serif',
#  'DejaVu Sans',
#  'STIXNonUnicode',
#  'STIXSizeOneSym',
#  'STIXSizeOneSym',
#  'DejaVu Sans',
#  'cmmi10',
#  'DejaVu Serif',
#  'DejaVu Sans Mono',
#  'DejaVu Serif Display',
#  'STIXGeneral',
#  'STIXNonUnicode',
#  'DejaVu Sans Mono',
#  'DejaVu Sans Display',
#  'DejaVu Sans Mono',
#  'STIXGeneral',
#  'DejaVu Sans',
#  'DejaVu Serif',
#  'STIXSizeTwoSym',
#  'cmss10',
#  'STIXNonUnicode',
#  'STIXGeneral',
#  'DejaVu Serif',
#  'STIXSizeFiveSym',
#  'STIXSizeThreeSym',
#  'cmr10',
#  'Leelawadee UI',
#  'Candara',
#  'Century Schoolbook',
#  'Palatino Linotype',
#  'HYHeadLine-Medium',
#  'Headline R',
#  'Agency FB',
#  'Arial Rounded MT Bold',
#  'Courier New',
#  'Showcard Gothic',
#  'Kristen ITC',
#  'Segoe UI',
#  'Constantia',
# ...

# %%
def kdeplot_sub_draw(sub_ax, x, title, size, color, left= 0, right= 0):
    # sns.kdeplot: Fit and plot a univariate or bivariate kernel density estimate
    if left != 0 and right != 0:
        sub_ax.set_xlim(left, right)
    sub_ax.grid(True)
    sub_ax.set_title(title)
    sns.kdeplot(x, ax = sub_ax, shade=True, color=color)
    # median  line draw
    sub_ax.set_xlabel(" ")

# %%
def kdeplot_show(a, b):
    fig, ax = plt.subplots(nrows=5, ncols=5, figsize=(25,20))
    kdeplot_sub_draw(sub_ax=ax[0][0], x=a['CBSCORE'], title='CBSCORE', size=1, color='g',left=-3,right=2)
    ax[0][0].axvline(x=a['CBSCORE'].median(), color='g', linestyle='--', linewidth=0.5)
    kdeplot_sub_draw(sub_ax=ax[0][0], x=b['CBSCORE'], title='CBSCORE', size=1, color='r',left=-3,right=2)
    ax[0][0].axvline(x=b['CBSCORE'].median(), color='r', linestyle='--', linewidth=0.5)
    ax[0][0].text(1,0.6,str(round(a['CBSCORE'].median()-b['CBSCORE'].median(),4)),fontsize=15)

    kdeplot_sub_draw(sub_ax=ax[0][1], x=a['CREDITOTAMT'], title='신용차입총액', size=1, color='g',left=-5,right=6)
    ax[0][1].axvline(x=a['CREDITOTAMT'].median(), color='g', linestyle='--', linewidth=0.5)
    kdeplot_sub_draw(sub_ax=ax[0][1], x=b['CREDITOTAMT'], title='신용차입총액', size=1, color='r',left=-5,right=6)
    ax[0][1].axvline(x=b['CREDITOTAMT'].median(), color='r', linestyle='--', linewidth=0.5)
    ax[0][1].text(3.1,0.45,str((round(a['CREDITOTAMT'].median()-b['CREDITOTAMT'].median()),4)),fontsize=15)


    kdeplot_sub_draw(sub_ax=ax[0][2], x=a['YSALEAMT'], title='연간환산매출액', size=1, color='g',left=-2,right=10)
    ax[0][2].axvline(x=a['YSALEAMT'].median(), color='g', linestyle='--', linewidth=0.5)
    kdeplot_sub_draw(sub_ax=ax[0][2], x=b['YSALEAMT'], title='연간환산매출액', size=1, color='r',left=-2,right=10)
    ax[0][2].axvline(x=b['YSALEAMT'].median(), color='r', linestyle='--', linewidth=0.5)
    ax[0][2].text(1,0.016,str(round(a['YSALEAMT'].median()-b['YSALEAMT'].median(),4)),fontsize=15)

    kdeplot_sub_draw(sub_ax=ax[0][3], x=a['ESTMM'], title='업력_월', size=1, color='g')
    ax[0][3].axvline(x=a['ESTMM'].median(), color='g', linestyle='--', linewidth=0.5)
    kdeplot_sub_draw(sub_ax=ax[0][3], x=b['ESTMM'], title='업력_월', size=1, color='r')
    ax[0][3].axvline(x=b['ESTMM'].median(), color='r', linestyle='--', linewidth=0.5)
    ax[0][3].text(1,0.016,str(round(a['ESTMM'].median()-b['ESTMM'].median(),4)),fontsize=15)
    
    kdeplot_sub_draw(sub_ax=ax[0][4], x=a['ASSETAMT'], title='자산가액', size=1, color='g' )
    ax[0][4].axvline(x=a['ASSETAMT'].median(), color='g', linestyle='--', linewidth=0.5)
    kdeplot_sub_draw(sub_ax=ax[0][4], x=b['ASSETAMT'], title='자산가액', size=1, color='r' )
    ax[0][4].axvline(x=b['ASSETAMT'].median(), color='r', linestyle='--', linewidth=0.5)
    ax[0][4].text(1,0.016,str(round(a['ASSETAMT'].median()-b['ASSETAMT'].median(),4)),fontsize=15)
    
    kdeplot_sub_draw(sub_ax=ax[1][0], x=a['IMSAAMT'], title='임차보증금사업장', size=1, color='g' )
    ax[1][0].axvline(x=a['IMSAAMT'].median(), color='g', linestyle='--', linewidth=0.5)
    kdeplot_sub_draw(sub_ax=ax[1][0], x=b['IMSAAMT'], title='임차보증금사업장', size=1, color='r' )
    ax[1][0].axvline(x=b['IMSAAMT'].median(), color='r', linestyle='--', linewidth=0.5)
    ax[1][0].text(1,0.016,str(round(a['IMSAAMT'].median()-b['IMSAAMT'].median(),4)),fontsize=15)
    
    kdeplot_sub_draw(sub_ax=ax[1][1], x=a['IMJUAMT'], title='임차보증금거주주택', size=1, color='g')
    ax[1][1].axvline(x=a['IMJUAMT'].median(), color='g', linestyle='--', linewidth=0.5)
    kdeplot_sub_draw(sub_ax=ax[1][1], x=b['IMJUAMT'], title='임차보증금거주주택', size=1, color='r')
    ax[1][1].axvline(x=b['IMJUAMT'].median(), color='r', linestyle='--', linewidth=0.5)
    ax[1][1].text(1,0.016,str(round(a['IMJUAMT'].median()-b['IMJUAMT'].median(),4)),fontsize=15)
    
    kdeplot_sub_draw(sub_ax=ax[1][2], x=a['BUSAAMT'], title='부동산사업장', size=1, color='g')
    ax[1][2].axvline(x=a['BUSAAMT'].median(), color='g', linestyle='--', linewidth=0.5)
    kdeplot_sub_draw(sub_ax=ax[1][2], x=b['BUSAAMT'], title='부동산사업장', size=1, color='r')
    ax[1][2].axvline(x=b['BUSAAMT'].median(), color='r', linestyle='--', linewidth=0.5)
    ax[1][2].text(1,0.016,str(round(a['BUSAAMT'].median()-b['BUSAAMT'].median(),4)),fontsize=15)
    
    kdeplot_sub_draw(sub_ax=ax[1][3], x=a['BUJUAMT'], title='부동산거주주택', size=1, color='g' )
    ax[1][3].axvline(x=a['BUJUAMT'].median(), color='g', linestyle='--', linewidth=0.5)
    kdeplot_sub_draw(sub_ax=ax[1][3], x=b['BUJUAMT'], title='부동산거주주택', size=1, color='r' )
    ax[1][3].axvline(x=b['BUJUAMT'].median(), color='r', linestyle='--', linewidth=0.5)
    ax[1][3].text(1,0.016,str(round(a['BUJUAMT'].median()-b['BUJUAMT'].median(),4)),fontsize=15)
    
    kdeplot_sub_draw(sub_ax=ax[1][4], x=a['BU1TOTAMT'], title='부실징후1대출합', size=1, color='g' )
    ax[1][4].axvline(x=a['BU1TOTAMT'].median(), color='g', linestyle='--', linewidth=0.5)
    kdeplot_sub_draw(sub_ax=ax[1][4], x=b['BU1TOTAMT'], title='부실징후1대출합', size=1, color='r' )
    ax[1][4].axvline(x=b['BU1TOTAMT'].median(), color='r', linestyle='--', linewidth=0.5)
    ax[1][4].text(1,0.6,str(round(a['BU1TOTAMT'].median()-b['BU1TOTAMT'].median(),4)),fontsize=15)
   
    kdeplot_sub_draw(sub_ax=ax[2][0], x=a['GAMT'], title='보증금액', size=1, color='g' )
    ax[2][0].axvline(x=a['GAMT'].median(), color='g', linestyle='--', linewidth=0.5)
    kdeplot_sub_draw(sub_ax=ax[2][0], x=a['GAMT'], title='보증금액', size=1, color='r' )
    ax[2][0].axvline(x=b['GAMT'].median(), color='r', linestyle='--', linewidth=0.5)
    ax[2][0].text(1,0.6,str(round(a['GAMT'].median()-b['GAMT'].median(),4)),fontsize=15)
    
    kdeplot_sub_draw(sub_ax=ax[2][1], x=a['GKIND'], title='보증종류', size=1, color='g' )
    ax[2][1].axvline(x=a['GKIND'].median(), color='g', linestyle='--', linewidth=0.5)
    kdeplot_sub_draw(sub_ax=ax[2][1], x=b['GKIND'], title='보증종류', size=1, color='r' )
    ax[2][1].axvline(x=b['GKIND'].median(), color='r', linestyle='--', linewidth=0.5)
    ax[2][1].text(1,0.6,str(round(a['GKIND'].median()-b['GKIND'].median(),4)),fontsize=15)

    kdeplot_sub_draw(sub_ax=ax[2][2], x=a['LABORCNT'], title='종업원수', size=1, color='g' )
    ax[2][2].axvline(x=a['LABORCNT'].median(), color='g', linestyle='--', linewidth=0.5)
    kdeplot_sub_draw(sub_ax=ax[2][2], x=b['LABORCNT'], title='종업원수', size=1, color='r' )
    ax[2][2].axvline(x=b['LABORCNT'].median(), color='r', linestyle='--', linewidth=0.5)
    ax[2][2].text(1,0.6,str(round(a['LABORCNT'].median()-b['LABORCNT'].median(),4)),fontsize=15)
    
    kdeplot_sub_draw(sub_ax=ax[2][3], x=a['ACTCD'], title='사고여부', size=1, color='g' )
    ax[2][3].axvline(x=a['ACTCD'].median(), color='g', linestyle='--', linewidth=0.5)
    kdeplot_sub_draw(sub_ax=ax[2][3], x=b['ACTCD'], title='사고여부', size=1, color='r' )
    ax[2][3].axvline(x=b['ACTCD'].median(), color='r', linestyle='--', linewidth=0.5)
    ax[2][3].text(1,0.6,str(round(a['ACTCD'].median()-b['ACTCD'].median(),4)),fontsize=15)
    
    kdeplot_sub_draw(sub_ax=ax[2][4], x=a['KOSPI'], title='KOSPI', size=1, color='g' )
    ax[2][4].axvline(x=a['KOSPI'].median(), color='g', linestyle='--', linewidth=0.5)
    kdeplot_sub_draw(sub_ax=ax[2][4], x=b['KOSPI'], title='KOSPI', size=1, color='r' )
    ax[2][4].axvline(x=b['KOSPI'].median(), color='r', linestyle='--', linewidth=0.5)
    ax[2][4].text(1,0.6,str(round(a['KOSPI'].median()-b['KOSPI'].median(),4)),fontsize=15)
    
    kdeplot_sub_draw(sub_ax=ax[3][0], x=a['환율'], title='환율', size=1, color='g' )
    ax[3][0].axvline(x=a['환율'].median(), color='g', linestyle='--', linewidth=0.5)
    kdeplot_sub_draw(sub_ax=ax[3][0], x=b['환율'], title='환율', size=1, color='r' )
    ax[3][0].axvline(x=b['환율'].median(), color='r', linestyle='--', linewidth=0.5)
    ax[3][0].text(1,0.6,str(round(a['환율'].median()-b['환율'].median(),4)),fontsize=15)
    
    kdeplot_sub_draw(sub_ax=ax[3][1], x=a['GDP'], title='GDP', size=1, color='g' )
    ax[3][1].axvline(x=a['GDP'].median(), color='g', linestyle='--', linewidth=0.5)
    kdeplot_sub_draw(sub_ax=ax[3][1], x=b['GDP'], title='GDP', size=1, color='r' )
    ax[3][1].axvline(x=b['GDP'].median(), color='r', linestyle='--', linewidth=0.5)
    ax[3][1].text(1,0.6,str(round(a['GDP'].median()-b['GDP'].median(),4)),fontsize=15)
    
    kdeplot_sub_draw(sub_ax=ax[3][2], x=a['소상공인체감지수'], title='소상공인BSI', size=1, color='g' )
    ax[3][2].axvline(x=a['소상공인체감지수'].median(), color='g', linestyle='--', linewidth=0.5)
    kdeplot_sub_draw(sub_ax=ax[3][2], x=b['소상공인체감지수'], title='소상공인BSI', size=1, color='r' )
    ax[3][2].axvline(x=b['소상공인체감지수'].median(), color='r', linestyle='--', linewidth=0.5)
    ax[3][2].text(1,0.6,str(round(a['소상공인체감지수'].median()-b['소상공인체감지수'].median(),4)),fontsize=15)
    
    kdeplot_sub_draw(sub_ax=ax[3][3], x=a['실업률'], title='실업률', size=1, color='g' )
    ax[3][3].axvline(x=a['실업률'].median(), color='g', linestyle='--', linewidth=0.5)
    kdeplot_sub_draw(sub_ax=ax[3][3], x=b['실업률'], title='실업률', size=1, color='r' )
    ax[3][3].axvline(x=b['실업률'].median(), color='r', linestyle='--', linewidth=0.5)
    ax[3][3].text(1,0.6,str(round(a['실업률'].median()-b['실업률'].median(),4)),fontsize=15)
  
    kdeplot_sub_draw(sub_ax=ax[3][4], x=a['물가지수'], title='물가지수', size=1, color='g' )
    ax[3][4].axvline(x=a['물가지수'].median(), color='g', linestyle='--', linewidth=0.5)
    kdeplot_sub_draw(sub_ax=ax[3][4], x=b['물가지수'], title='물가지수', size=1, color='r' )
    ax[3][4].axvline(x=b['물가지수'].median(), color='r', linestyle='--', linewidth=0.5)
    ax[3][4].text(1,0.6,str(round(a['물가지수'].median()-b['물가지수'].median(),4)),fontsize=15)
    
    kdeplot_sub_draw(sub_ax=ax[4][0], x=a['국고채'], title='국고채수익률', size=1, color='g' )
    ax[4][0].axvline(x=a['국고채'].median(), color='g', linestyle='--', linewidth=0.5)
    kdeplot_sub_draw(sub_ax=ax[4][0], x=b['국고채'], title='국고채수익률', size=1, color='r' )
    ax[4][0].axvline(x=b['국고채'].median(), color='r', linestyle='--', linewidth=0.5)
    ax[4][0].text(1,0.6,str(round(a['국고채'].median()-b['국고채'].median(),4)),fontsize=15)
    
    kdeplot_sub_draw(sub_ax=ax[4][1], x=a['금리'], title='금리', size=1, color='g' )
    ax[4][1].axvline(x=a['금리'].median(), color='g', linestyle='--', linewidth=0.5)
    kdeplot_sub_draw(sub_ax=ax[4][1], x=b['금리'], title='금리', size=1, color='r' )
    ax[4][1].axvline(x=b['금리'].median(), color='r', linestyle='--', linewidth=0.5)
    ax[4][1].text(1,0.6,str(round(a['금리'].median()-b['금리'].median(),4)),fontsize=15)
    
    kdeplot_sub_draw(sub_ax=ax[4][2], x=a['유가등락률'], title='WTI현물유가등락률', size=1, color='g' )
    ax[4][2].axvline(x=a['유가등락률'].median(), color='g', linestyle='--', linewidth=0.5)
    kdeplot_sub_draw(sub_ax=ax[4][2], x=b['유가등락률'], title='WTI현물유가등락률', size=1, color='r' )
    ax[4][2].axvline(x=b['유가등락률'].median(), color='r', linestyle='--', linewidth=0.5)
    ax[4][2].text(1,0.6,str(round(a['유가등락률'].median()-b['유가등락률'].median(),4)),fontsize=15)
    
    kdeplot_sub_draw(sub_ax=ax[4][3], x=a['소비자심리지수'], title='소비자심리지수', size=1, color='g' )
    ax[4][3].axvline(x=a['소비자심리지수'].median(), color='g', linestyle='--', linewidth=0.5)
    kdeplot_sub_draw(sub_ax=ax[4][3], x=b['소비자심리지수'], title='소비자심리지수', size=1, color='r' )
    ax[4][3].axvline(x=b['소비자심리지수'].median(), color='r', linestyle='--', linewidth=0.5)
    ax[4][3].text(1,0.6,str(round(a['소비자심리지수'].median()-b['소비자심리지수'].median(),4)),fontsize=15)
    
    kdeplot_sub_draw(sub_ax=ax[4][4], x=a['ONEHOT'], title='업종', size=1, color='g',left=-2,right=2)
    ax[4][4].axvline(x=a['ONEHOT'].median(), color='g', linestyle='--', linewidth=0.5)
    kdeplot_sub_draw(sub_ax=ax[4][4], x=b['ONEHOT'], title='업종', size=1, color='r',left=-2,right=2)
    ax[4][4].axvline(x=b['ONEHOT'].median(), color='r', linestyle='--', linewidth=0.5)
    ax[4][4].text(1,0.6,str(round(a['ONEHOT'].median()-b['ONEHOT'].median(),4)),fontsize=15)
    
    


kdeplot_show(data, df_bu)
# Out:
# C:\Users\user\anaconda3\envs\Study_Big\lib\site-packages\seaborn\distributions.py:316: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   warnings.warn(msg, UserWarning)
